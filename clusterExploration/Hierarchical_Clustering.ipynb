# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("MAP01938_0000_0E_01_region_001_quantification.csv")

# %%
df
# Out:
#        label  area    centroid-0   centroid-1  intensity_mean_ACTININ  \
# 0          1  1726    214.335458  3238.139050             1377.181918
# 1          2   598    194.466555  3177.015050             1283.824211
# 2          3  1819    207.032985  3296.256185              448.431373
# 3          4  1016    215.551181  3351.617126             2001.734967
# 4          5  2186    257.050778  3482.407594             5871.192534
# ...      ...   ...           ...          ...                     ...
# 58897  35198   917  20746.541985  9091.269357             1791.429662
# 58898  35199   140  20743.685714  7715.028571             5490.907143
# 58899  35200   879  20767.001138  9043.136519             2632.098976
# 58900  35201   130  20745.761538  7727.015385             8424.507692
# 58901  35202   677  20770.731167  9064.161004             8792.914328
#
#        intensity_mean_BCATENIN  intensity_mean_CD11B  intensity_mean_CD20  \
# 0                  5453.981257             70.351709           222.284454
# 1                  5617.212632             77.549474           156.285263
# 2                   912.377709             74.875129            51.247678
# 3                  1037.945991             48.752227            98.216592
# 4                 15568.954813              0.000000           330.662083
# ...                        ...                   ...                  ...
# 58897              1028.886587              9.256270           262.069793
# 58898              5731.807143              0.900000           424.900000
# 58899              4124.544937              6.835040           273.275313
# 58900              9337.376923              0.007692           374.938462
# 58901             13922.162482              3.444609           404.113737
#
#        intensity_mean_CD3D  intensity_mean_CD45B  ...  intensity_mean_PDL1  \
# 0              2814.541345              0.000000  ...             1.087100
# 1              2136.020000              0.151579  ...             2.584211
# 2               946.068111              1.306502  ...             1.625387
# 3              1889.127506              0.291203  ...             2.927617
# 4              4432.709234              0.000000  ...             2.785855
# ...                    ...                   ...  ...                  ...
# 58897           284.822246              0.000000  ...             0.000000
# 58898           874.192857              0.000000  ...             0.000000
# 58899           396.904437              0.000000  ...             1.720137
# 58900           992.576923              0.000000  ...             2.415385
# 58901           497.564254              0.000000  ...             1.446086
#
#        intensity_mean_PEGFR  intensity_mean_PSTAT3  intensity_mean_SMA  \
# 0               1813.503859             670.190739           37.188534
# 1               1931.118947             546.755789           28.677895
# 2                731.348813             109.764706           22.675955
# 3               1457.570156             213.432628           21.036748
# 4               3564.607073            1225.677800           43.414538
# ...                     ...                    ...                 ...
# 58897            893.420938              18.015267         1706.593239
# 58898           2022.328571              63.128571           64.878571
# 58899           1509.091013              33.367463           38.854380
# 58900           2554.600000              47.146154           50.423077
# 58901           3874.298375              54.161004          256.685377
#
#        intensity_mean_SNA  intensity_mean_SOX9  intensity_mean_VIMENTIN  \
# 0             3938.164278           179.209482                 0.020948
# 1             3261.632632           187.389474                 0.038947
# 2             1341.295150            84.295150                 0.000000
# 3             1860.204343           283.033964                 0.000000
# 4             6724.858546           461.563851                 0.000000
# ...                   ...                  ...                      ...
# 58897         3084.959651            20.707743               855.295529
# 58898         3267.242857           890.614286                 0.000000
# 58899         2599.758817           390.435722                 0.000000
# 58900         3424.707692           246.923077                 0.000000
# 58901         3547.147710             6.946824                66.943870
#
#        epithelial                slide  region
# 0               1  MAP01938_0000_0E_01       1
# 1               1  MAP01938_0000_0E_01       1
# 2               1  MAP01938_0000_0E_01       1
# 3               1  MAP01938_0000_0E_01       1
# 4               1  MAP01938_0000_0E_01       1
# ...           ...                  ...     ...
# 58897           0  MAP01938_0000_0E_01       1
# 58898           0  MAP01938_0000_0E_01       1
# 58899           0  MAP01938_0000_0E_01       1
# 58900           0  MAP01938_0000_0E_01       1
# 58901           0  MAP01938_0000_0E_01       1
#
# [58902 rows x 38 columns]

# %%
all_columns = df.columns

# %%
filtered_columns = [col for col in all_columns if col.startswith('intensity')]

# %%
data = df[filtered_columns]

# %%
data = data.dropna()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data[filtered_columns] = scaler.fit_transform(data[filtered_columns])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from sklearn.preprocessing import StandardScaler
#       2 scaler = StandardScaler()
#       3 data[filtered_columns] = scaler.fit_transform(data[filtered_columns])
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
data.head()
# Out:
#    intensity_mean_ACTININ  intensity_mean_BCATENIN  intensity_mean_CD11B  \
# 0               -0.755419                -0.237702             -0.047996
# 1               -0.799895                -0.213898             -0.023839
# 2               -1.197875                -0.900008             -0.032814
# 3               -0.457883                -0.881696             -0.120490
# 4                1.385521                 1.237374             -0.284115
#
#    intensity_mean_CD20  intensity_mean_CD3D  intensity_mean_CD45B  \
# 0            -0.622719             0.152231             -0.044486
# 1            -0.788653            -0.061467             -0.043870
# 2            -1.052736            -0.436238             -0.039173
# 3            -0.934648            -0.139225             -0.043302
# 4            -0.350239             0.661867             -0.044486
#
#    intensity_mean_CD45  intensity_mean_CD4  intensity_mean_CD68  \
# 0             0.054639           -0.504455             0.066253
# 1             0.002105           -0.614208            -0.177764
# 2            -0.201038           -0.816104            -0.582970
# 3            -0.135653           -0.758715            -0.520100
# 4            -0.299421           -0.252078             0.689533
#
#    intensity_mean_CD8  ...  intensity_mean_OLFM4  intensity_mean_PANCK  \
# 0           -0.129610  ...             -0.271555              2.927413
# 1           -0.209365  ...             -0.212641              1.945312
# 2           -0.531601  ...             -0.349716             -0.270893
# 3           -0.391918  ...             -0.201169              0.192214
# 4            0.427360  ...              0.328158              1.644865
#
#    intensity_mean_PCNA  intensity_mean_PDL1  intensity_mean_PEGFR  \
# 0            -0.580986            -0.024708             -0.116328
# 1            -0.602728            -0.020434             -0.033674
# 2            -0.815051            -0.023171             -0.876807
# 3            -0.811334            -0.019454             -0.366458
# 4             0.342401            -0.019859              1.114251
#
#    intensity_mean_PSTAT3  intensity_mean_SMA  intensity_mean_SNA  \
# 0               0.689205           -0.282520           -0.144310
# 1               0.424434           -0.285476           -0.425633
# 2              -0.512923           -0.287560           -1.224171
# 3              -0.290553           -0.288129           -1.008392
# 4               1.880740           -0.280358            1.014486
#
#    intensity_mean_SOX9  intensity_mean_VIMENTIN
# 0            -0.501915                -0.513531
# 1            -0.496134                -0.513517
# 2            -0.569001                -0.513548
# 3            -0.428532                -0.513548
# 4            -0.302347                -0.513548
#
# [5 rows x 31 columns]

# %%
correlation_matrix = data.corr()

# %%
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', center=0)
plt.title("Correlation Heatmap")
plt.show()

# %%
mod_data = df[filtered_columns]
mean_values = np.mean(mod_data , axis=0)
std_dev_values = np.std(mod_data , axis=0)
min_values = np.min(mod_data , axis=0)
max_values = np.max(mod_data , axis=0)

# %%
for i in range(mod_data.shape[1]):
    print(f"Feature {i + 1}:")
    print(f"  Mean: {mean_values[i]:.2f}")
    print(f"  Standard Deviation: {std_dev_values[i]:.2f}")
    print(f"  Min: {min_values[i]:.2f}")
    print(f"  Max: {max_values[i]:.2f}")
    print("----------------------")
# Out:
# Feature 1:
#   Mean: 2962.87
#   Standard Deviation: 2099.08
#   Min: 0.00
#   Max: 24475.74
# ----------------------
# Feature 2:
#   Mean: 7083.96
#   Standard Deviation: 6857.26
#   Min: 0.00
#   Max: 63540.48
# ----------------------
# Feature 3:
#   Mean: 84.65
#   Standard Deviation: 297.95
#   Min: 0.00
#   Max: 12512.22
# ----------------------
# Feature 4:
#   Mean: 469.97
#   Standard Deviation: 397.74
#   Min: 1.71
#   Max: 16589.51
# ----------------------
# Feature 5:
#   Mean: 2331.19
#   Standard Deviation: 3175.14
#   Min: 0.00
#   Max: 46509.16
# ----------------------
# Feature 6:
#   Mean: 10.94
#   Standard Deviation: 245.89
#   Min: 0.00
#   Max: 17547.97
# ----------------------
# Feature 7:
#   Mean: 103.65
#   Standard Deviation: 346.17
#   Min: 0.00
#   Max: 52319.48
# ----------------------
# Feature 8:
#   Mean: 1706.72
#   Standard Deviation: 1809.01
#   Min: 0.00
#   Max: 31757.52
# ----------------------
# Feature 9:
#   Mean: 990.16
#   Standard Deviation: 1493.04
#   Min: 0.00
#   Max: 47104.77
# ----------------------
# Feature 10:
#   Mean: 560.46
#   Standard Deviation: 650.59
#   Min: 0.00
#   Max: 25977.73
# ----------------------
# Feature 11:
#   Mean: 298.57
#   Standard Deviation: 187.06
#   Min: 0.00
#   Max: 15616.38
# ----------------------
# Feature 12:
#   Mean: 718.59
#   Standard Deviation: 805.40
#   Min: 0.00
#   Max: 10524.24
# ----------------------
# Feature 13:
#   Mean: 323.60
#   Standard Deviation: 171.63
#   Min: 0.00
#   Max: 7109.21
# ----------------------
# Feature 14:
#   Mean: 4572.96
#   Standard Deviation: 3155.10
#   Min: 115.89
#   Max: 33478.00
# ----------------------
# Feature 15:
#   Mean: 1925.24
#   Standard Deviation: 1992.30
#   Min: 0.00
#   Max: 42425.28
# ----------------------
# Feature 16:
#   Mean: 7.43
#   Standard Deviation: 142.36
#   Min: 0.00
#   Max: 16944.75
# ----------------------
# Feature 17:
#   Mean: 1886.68
#   Standard Deviation: 1201.32
#   Min: 0.00
#   Max: 22774.00
# ----------------------
# Feature 18:
#   Mean: 2637.98
#   Standard Deviation: 1853.26
#   Min: 12.50
#   Max: 24456.51
# ----------------------
# Feature 19:
#   Mean: 305.46
#   Standard Deviation: 956.96
#   Min: 0.00
#   Max: 29797.71
# ----------------------
# Feature 20:
#   Mean: 1696.16
#   Standard Deviation: 2348.17
#   Min: 0.00
#   Max: 41458.84
# ----------------------
# Feature 21:
#   Mean: 3161.17
#   Standard Deviation: 2968.13
#   Min: 14.07
#   Max: 45241.60
# ----------------------
# Feature 22:
#   Mean: 379.35
#   Standard Deviation: 862.59
#   Min: 0.00
#   Max: 21755.14
# ----------------------
# Feature 23:
#   Mean: 1851.80
#   Standard Deviation: 2405.01
#   Min: 0.00
#   Max: 56677.07
# ----------------------
# Feature 24:
#   Mean: 860.71
#   Standard Deviation: 1013.11
#   Min: 0.00
#   Max: 11841.44
# ----------------------
# Feature 25:
#   Mean: 9.74
#   Standard Deviation: 350.32
#   Min: 0.00
#   Max: 30444.16
# ----------------------
# Feature 26:
#   Mean: 1979.04
#   Standard Deviation: 1422.99
#   Min: 0.00
#   Max: 21824.06
# ----------------------
# Feature 27:
#   Mean: 348.89
#   Standard Deviation: 466.19
#   Min: 0.00
#   Max: 25861.90
# ----------------------
# Feature 28:
#   Mean: 850.80
#   Standard Deviation: 2879.82
#   Min: 0.00
#   Max: 63358.24
# ----------------------
# Feature 29:
#   Mean: 4285.20
#   Standard Deviation: 2404.82
#   Min: 260.76
#   Max: 64434.37
# ----------------------
# Feature 30:
#   Mean: 889.33
#   Standard Deviation: 1414.83
#   Min: 0.00
#   Max: 29626.76
# ----------------------
# Feature 31:
#   Mean: 647.82
#   Standard Deviation: 1261.46
#   Min: 0.00
#   Max: 17658.06
# ----------------------

# %%
columns_to_drop = ['intensity_mean_CD11B', 'intensity_mean_CD45B', 'intensity_mean_FOXP3','intensity_mean_PDL1']
data = data.drop(columns_to_drop, axis=1)

# %%
data
# Out:
#        intensity_mean_ACTININ  intensity_mean_BCATENIN  intensity_mean_CD20  \
# 0                   -0.755419                -0.237702            -0.622719
# 1                   -0.799895                -0.213898            -0.788653
# 2                   -1.197875                -0.900008            -1.052736
# 3                   -0.457883                -0.881696            -0.934648
# 4                    1.385521                 1.237374            -0.350239
# ...                       ...                      ...                  ...
# 58897               -0.558072                -0.883017            -0.522692
# 58898                1.204353                -0.197186            -0.113309
# 58899               -0.157579                -0.431575            -0.494520
# 58900                2.601917                 0.328617            -0.238921
# 58901                2.777425                 0.997221            -0.165569
#
#        intensity_mean_CD3D  intensity_mean_CD45  intensity_mean_CD4  \
# 0                 0.152231             0.054639           -0.504455
# 1                -0.061467             0.002105           -0.614208
# 2                -0.436238            -0.201038           -0.816104
# 3                -0.139225            -0.135653           -0.758715
# 4                 0.661867            -0.299421           -0.252078
# ...                    ...                  ...                 ...
# 58897            -0.644495            -0.287815           -0.229687
# 58898            -0.458875            -0.299421           -0.291303
# 58899            -0.609196            -0.268771           -0.410531
# 58900            -0.421591            -0.299421           -0.268896
# 58901            -0.577493            -0.299310           -0.226688
#
#        intensity_mean_CD68  intensity_mean_CD8  intensity_mean_CGA  \
# 0                 0.066253           -0.129610           -1.003902
# 1                -0.177764           -0.209365           -0.810423
# 2                -0.582970           -0.531601           -0.789268
# 3                -0.520100           -0.391918           -1.060493
# 4                 0.689533            0.427360           -0.778327
# ...                    ...                 ...                 ...
# 58897            -0.461287           -0.675472            0.335013
# 58898            -0.081893           -0.069617           -0.014309
# 58899            -0.400156           -0.607317            0.167137
# 58900            -0.140509            0.088755            0.025618
# 58901            -0.191237           -0.392278           -0.196239
#
#        intensity_mean_COLLAGEN  ...  intensity_mean_NAKATPASE  \
# 0                    -0.364623  ...                 -0.358085
# 1                    -0.600941  ...                 -0.370080
# 2                    -0.847000  ...                 -0.952934
# 3                    -0.739680  ...                 -0.828515
# 4                    -0.138731  ...                  0.728570
# ...                        ...  ...                       ...
# 58897                 1.037469  ...                 -0.701773
# 58898                -0.167209  ...                  0.152984
# 58899                -0.718043  ...                 -0.002500
# 58900                -0.194361  ...                  1.082482
# 58901                 0.208012  ...                  2.503326
#
#        intensity_mean_OLFM4  intensity_mean_PANCK  intensity_mean_PCNA  \
# 0                 -0.271555              2.927413            -0.580986
# 1                 -0.212641              1.945312            -0.602728
# 2                 -0.349716             -0.270893            -0.815051
# 3                 -0.201169              0.192214            -0.811334
# 4                  0.328158              1.644865             0.342401
# ...                     ...                   ...                  ...
# 58897             -0.367010             -0.640377            -0.751786
# 58898              0.000229              0.185662            -0.218189
# 58899             -0.329197             -0.025927            -0.385363
# 58900             -0.072803              0.368764            -0.368726
# 58901             -0.260934              0.712120            -0.601301
#
#        intensity_mean_PEGFR  intensity_mean_PSTAT3  intensity_mean_SMA  \
# 0                 -0.116328               0.689205           -0.282520
# 1                 -0.033674               0.424434           -0.285476
# 2                 -0.876807              -0.512923           -0.287560
# 3                 -0.366458              -0.290553           -0.288129
# 4                  1.114251               1.880740           -0.280358
# ...                     ...                    ...                 ...
# 58897             -0.762911              -0.709728            0.297170
# 58898              0.030423              -0.612959           -0.272905
# 58899             -0.330252              -0.676797           -0.281942
# 58900              0.404474              -0.647242           -0.277925
# 58901              1.331885              -0.632194           -0.206302
#
#        intensity_mean_SNA  intensity_mean_SOX9  intensity_mean_VIMENTIN
# 0               -0.144310            -0.501915                -0.513531
# 1               -0.425633            -0.496134                -0.513517
# 2               -1.224171            -0.569001                -0.513548
# 3               -1.008392            -0.428532                -0.513548
# 4                1.014486            -0.302347                -0.513548
# ...                   ...                  ...                      ...
# 58897           -0.499099            -0.613945                 0.164475
# 58898           -0.423300             0.000906                -0.513548
# 58899           -0.700861            -0.352621                -0.513548
# 58900           -0.357821            -0.454055                -0.513548
# 58901           -0.306907            -0.623671                -0.460479
#
# [58902 rows x 27 columns]

# %%
import scipy.cluster.hierarchy as shc
data = data.iloc[0:30000]
plt.figure(figsize=(10, 7))
plt.title("Dendrograms")
dend = shc.dendrogram(shc.linkage(data, method='ward'))

# %%
from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(
    n_clusters=3, affinity='euclidean', linkage='ward')

cluster.fit(data.values)
labels = cluster.labels_
labels
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# array([1, 1, 0, ..., 2, 2, 2])

# %%
from sklearn.decomposition import PCA

cluster = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')
cluster_labels = cluster.fit_predict(data.values)

pca = PCA(n_components=2)
pca_result = pca.fit_transform(data.values)

pca_df = pd.DataFrame({'PCA1': pca_result[:, 0], 'PCA2': pca_result[:, 1], 'Cluster': cluster_labels})

plt.figure(figsize=(10, 6))
plt.scatter(pca_df['PCA1'], pca_df['PCA2'], c=pca_df['Cluster'])
plt.title('2D PCA Visualization of Clusters')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.colorbar(label='Cluster')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
