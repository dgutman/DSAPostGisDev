# %%
import girder_client
import json
import requests
with open("./multiPatientGridData.json") as fp:
    mpgd = json.load(fp)

# %%
import pprint

dbApiUrl = "http://localhost:82/"

for i in mpgd:
    print(i['apiURL'])
    print(i['imageId'])
#    requests.post("http://i['apiURL'], i['imageId']
    r = requests.post(dbApiUrl+"add-DSAImage/?imageId=%s&dsaApiUrl=%s" % (i['imageId'], i['apiURL']))
# Out:
# http://api.digitalslidearchive.org/api/v1
# 5b9efefee62914002e94b6c6
# http://api.digitalslidearchive.org/api/v1
# 5b9efefee62914002e94b6cb
# http://api.digitalslidearchive.org/api/v1
# 5b9efefee62914002e94b6d1
# http://api.digitalslidearchive.org/api/v1
# 5b9efeffe62914002e94b6d6
# http://imaging.htan.dev/girder/api/v1
# 5b9efeffe62914002e94b6d6

# %%
# Out:
# {'downSampleFactor': 64,
#  'gridData': [{'height': 1024,
#                'imgHistogram': {'average': [239.77344, 239.89844, 239.48438],
#                                 'blue': [0, 0, 0, 0, 0, 0, 0, 0, 6, 250],
#                                 'green': [0, 0, 0, 0, 0, 0, 0, 0, 6, 250],
#                                 'red': [0, 0, 0, 0, 0, 0, 0, 0, 6, 250]},
#                'topX': 0,
#                'topY': 0,
#                'width': 1024},
#               {'height': 1024,
#                'imgHistogram': {'average': [242.84375, 243.0625, 242.82812],
#                                 'blue': [0, 0, 0, 0, 0, 0, 0, 0, 0, 256],
#                                 'green': [0, 0, 0, 0, 0, 0, 0, 0, 0, 256],
#                                 'red': [0, 0, 0, 0, 0, 0, 0, 0, 0, 256]},
#                'topX': 0,
#                'topY': 1024,
#                'width': 1024},
#               {'height': 1024,
# ...

# %%
def generateImageGrid(imageId, apiURL ):
    print("YO")
